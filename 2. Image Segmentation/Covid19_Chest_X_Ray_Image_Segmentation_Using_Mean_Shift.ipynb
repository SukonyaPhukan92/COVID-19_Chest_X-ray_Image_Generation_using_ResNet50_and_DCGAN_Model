# %% [markdown]
# # **Step 1: Importing the required libraries**

# %%
import cv2
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imsave
from google.colab.patches import cv2_imshow 
from skimage.color import rgb2lab
from sklearn.cluster import MeanShift, estimate_bandwidth

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Step 2: Performing Mean Shift Segmentation technique on Enhanced Covid-19 Chest X-ray images**

# %%
folder='/content/drive/MyDrive/NIT DGP Internship/covid19_enhanced_images'
def load_images_from_folder(folder):
    images = []
count=0
for filename in os.listdir(folder):
   a = cv2.imread(os.path.join(folder,filename))
   #cv2_imshow(a)
   fimage = cv2.cvtColor(a, cv2.COLOR_BGR2LAB)
   originShape = fimage.shape
   flatImg=np.reshape(fimage, [-1, 3])
   
   # Estimate bandwidth for meanshift algorithm    
   bandwidth = estimate_bandwidth(flatImg, quantile=0.1, n_samples=100)    
   ms = MeanShift(bandwidth = bandwidth, bin_seeding=True)
   
   # Performing meanshift on flatI mg    
   ms.fit(flatImg)
   
   # (r,g,b) vectors corresponding to the different clusters after meanshift    
   labels=ms.labels_
   
   # Remaining colors after meanshift    
   cluster_centers = ms.cluster_centers_    
   
   # Finding and diplaying the number of clusters    
   labels_unique = np.unique(labels)    
   n_clusters_ = len(labels_unique)    
   #print("number of estimated clusters : %d" % n_clusters_)
   count+=1
   segmentedImg = np.reshape(labels, originShape[:2])
   imsave('/content/drive/MyDrive/NIT DGP Internship/COVID19 Chest X-Ray Segmented Images using Meanshift/MeanShift_Output'+str(count)+'.png',segmentedImg)
   #cv2.imwrite('/content/drive/MyDrive/NIT DGP Internship/output/output'+str(count)+'.png', segmentedImg)
   #cv2_imshow(segmentedImg)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/NIT DGP Internship/COVID19 Chest X-Ray Segmented Images using Meanshift/MeanShift_Output1308.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/NIT DGP Internship/COVID19 Chest X-Ray Segmented Images using Meanshift/MeanShift_Output1309.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 9]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/NIT DGP Internship/COVID19 Chest X-Ray Segmented Images using Meanshift/MeanShift_Output1310.png is a low contrast image
# ...

# %%
if __name__=="__main__":
    load_images_from_folder(folder)
