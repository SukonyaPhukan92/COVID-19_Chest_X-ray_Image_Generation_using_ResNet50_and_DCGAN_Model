# %% [markdown]
# # **Step 1: Importing the required libraries**

# %%
import numpy as np
import cv2
import os
import glob
import matplotlib.pyplot as plt
from skimage.io import imsave
from google.colab.patches import cv2_imshow
from PIL import Image, ImageOps
from matplotlib import cm
from PIL import ImageFilter 
import matplotlib.image as mpimg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Step 2: Performing Fuzzy C-means Segmentation technique on Enhanced Covid-19 Chest X-ray images**

# %%
def init_mem_mat(nb_pixels, nb_clusters):
    mem_mat = np.zeros((nb_pixels, nb_clusters))
    x = np.arange(nb_pixels)
    for j in range(nb_clusters):
        xj = x % nb_clusters == j
        mem_mat[xj, j] = 1

    return mem_mat

# %%
def compute_centers(img_mat, mem_mat, fuzzy):
    num = np.dot(img_mat, mem_mat ** fuzzy)
    dem = np.sum(mem_mat ** fuzzy, axis=0)

    return num / dem

# %%
def update_mem_mat(ctr_mat, img_mat, fuzzy):
    ctr_mat_mesh, img_mat_mesh = np.meshgrid(ctr_mat, img_mat)
    power = 2. / (fuzzy - 1)
    p1 = abs(img_mat_mesh - ctr_mat_mesh) ** power
    p2 = np.sum((1. / abs(img_mat_mesh - ctr_mat_mesh)) ** power, axis=1)

    return 1. / (p1 * p2[:, None])

# %%
folder='/content/drive/MyDrive/NIT DGP Internship/covid19_enhanced_images'
def load_images_from_folder(folder):
  images = []
count=0
for f in os.listdir(folder):
  img = cv2.imread(os.path.join(folder,f))
  #cv2_imshow(img)
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  #plt.show()
  #cv2_imshow(gray)
  K = 2
  N = gray.size
  m = 2
  eps = 0.3
  max_i = 100
  X = gray.flatten().astype('float')
  U = init_mem_mat(N, K)
  i = 0
  while True:
    C = compute_centers(X, U, m)

    # Save initial membership matrix
    old_U = np.copy(U)

    # Update coefficients for each pixel
    U = update_mem_mat(C, X, m)

    # Difference between initial mem matrix and new one
    d = np.sum(abs(U - old_U))
    #print(str(i) + " - d = " + str(d))

    # Check convergence
    if d < eps or i > max_i:
        break
    i += 1
  count += 1
  #cv2_imshow(gray)
  seg = np.argmax(U, axis=1)
  seg = seg.reshape(gray.shape).astype('int')
  #print(type(seg))
  imsave('/content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output'+str(count)+'.png',seg)
  #cv2_imshow(seg)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1324.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1325.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1326.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1327.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1328.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1329.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1330.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1331.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1332.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1333.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1334.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1335.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1336.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1337.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1338.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1339.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1340.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1341.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1342.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1343.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1344.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1345.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1346.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1347.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1348.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1349.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1350.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1351.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1352.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1353.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1354.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1355.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1356.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1357.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1358.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1359.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1360.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1361.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1362.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1363.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1364.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1365.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1366.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1367.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1368.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1369.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1370.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1371.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1372.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1373.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1374.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1375.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1376.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1377.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1378.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1379.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1380.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1381.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1382.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1383.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1384.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1385.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1386.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1387.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1388.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1389.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1390.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1391.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1392.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1393.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1394.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1395.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1396.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1397.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1398.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1399.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1400.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1401.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1402.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1403.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1404.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1405.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1406.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1407.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1408.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1409.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1410.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1411.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1412.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1413.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1414.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1415.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1416.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1417.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1418.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1419.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1420.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1421.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1422.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1423.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1424.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1425.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1426.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1427.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1428.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1429.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1430.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1431.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1432.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1433.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1434.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1435.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1436.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1437.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1438.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1439.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1440.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1441.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1442.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1443.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1444.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1445.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1446.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1447.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1448.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1449.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1450.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1451.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1452.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1453.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1454.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1455.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1456.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1457.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output1458.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3791.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3792.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3793.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3794.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3795.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3796.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3797.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3798.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3799.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3800.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3801.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3802.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3803.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3804.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3805.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3806.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3807.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3808.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3809.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3810.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3811.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3812.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3813.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3814.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3815.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3816.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3817.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3818.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3819.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3820.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3821.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3822.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3823.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3824.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3825.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3826.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3827.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3828.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3829.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3830.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3831.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3832.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3833.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3834.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: /content/drive/MyDrive/NIT DGP Internship/Covid 19 Chest X-Ray Segmented Images using Fuzzc C Means /Fuzzy_Output3835.png is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
if __name__=="__main__":
    load_images_from_folder(folder)
